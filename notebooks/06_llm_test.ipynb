# %% [markdown]
# ## Test Gemini API

# %%
from financial_rag.llm.gemini import get_gemini_llm

llm = get_gemini_llm()

response = llm.invoke(
    "Explain credit risk policy in one simple sentence."
)

print(response.content)
# Out:
# [{'type': 'text', 'text': 'A credit risk policy is a set of guidelines that defines who a business will lend money to and how it will manage the risk of those borrowers failing to pay back their debts.', 'extras': {'signature': 'EnEKbwERTTIP+25w3kCiPaGVLcNrfSfZ6N/077PxgN3OfQ2Rg50ymKaasJnox3kQaFh7fuGhuBtEMZ8PZMtFYRDy4bM/qXQJxc0gJbyzS3h16lGmV72v7asNKk+Kqhfuw1RB18LJv/MJYz7yAjBLUxpurQ=='}}]

# %% [markdown]
# ## Test Groq API

# %%
from financial_rag.llm.groq import get_groq_llm

llm = get_groq_llm()

response = llm.invoke(
    "Explain credit risk policy in one simple sentence."
)

print(response.content)
# Out:
# A credit risk policy is a set of guidelines that define how a lender evaluates, approves, monitors, and manages the risk of borrowers defaulting on their loans.

# %% [markdown]
# ## Test Router Gateway for Fallback API

# %%
from financial_rag.llm.router import generate_response

response, provider = generate_response(
    "Explain credit risk policy in one simple sentence."
)

print("Provider:", provider)
print("Response:", response)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# Provider: gemini
# Response: [{'type': 'text', 'text': 'A credit risk policy is a set of guidelines that defines who a business will lend money to and how it will manage the risk of those borrowers failing to pay back their debts.', 'extras': {'signature': 'EnEKbwERTTIPVcLEjuJ46QBbJzsn3zQze18PumgGnDzLA1EkAg3MK1f35c7cbbiy4j3wMiYZJingMmcYg8MR8elRYs2JqVqHDkGil0Aj5UDni82tDeEXVfR108zGziln/cmIZV79/KreIHy4OFpcSvTiMQ=='}}]
